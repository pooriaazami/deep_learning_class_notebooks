# %% [markdown]
# <a href="https://colab.research.google.com/github/pooriaazami/deep_learning_class_notebooks/blob/main/Fashion_MNIST_and_CIFAR10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.layers as layers

import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
idx = 20
plt.imshow(x_train[idx], cmap='gray')
plt.show()

# %%
x_train_flattened = x_train.reshape(-1, 28 * 28)
x_test_flattened = x_test.reshape(-1, 28 * 28)

# %%
x_train_flattened = x_train_flattened / 255.
x_test_flattened = x_test_flattened / 255.

# %%
model = keras.Sequential([
    keras.Input(28 * 28, name='input_layer'),
    keras.layers.Dense(128, activation='relu', name='fc_1'),
    keras.layers.Dense(128, activation='relu', name='fc_2'),
    keras.layers.Dense(10, activation='softmax', name='output_layer')
], name='mnist_classifier')

# %%
model.summary()
# Out:
# Model: "mnist_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  fc_1 (Dense)                (None, 128)               100480
#
#  fc_2 (Dense)                (None, 128)               16512
#
#  output_layer (Dense)        (None, 10)                1290
#
# =================================================================
# Total params: 118282 (462.04 KB)
# Trainable params: 118282 (462.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='sgd',
    metrics=['accuracy']
)

# %%
history = model.fit(x_train_flattened,
          y_train,
          validation_data=(x_test_flattened, y_test),
          epochs=10,
          batch_size=32,
)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 16s 6ms/step - loss: 0.7376 - accuracy: 0.7582 - val_loss: 0.5561 - val_accuracy: 0.8065
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4923 - accuracy: 0.8276 - val_loss: 0.4842 - val_accuracy: 0.8290
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4497 - accuracy: 0.8415 - val_loss: 0.4655 - val_accuracy: 0.8356
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4219 - accuracy: 0.8505 - val_loss: 0.4434 - val_accuracy: 0.8420
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4027 - accuracy: 0.8577 - val_loss: 0.4203 - val_accuracy: 0.8500
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3868 - accuracy: 0.8632 - val_loss: 0.4148 - val_accuracy: 0.8503
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3740 - accuracy: 0.8673 - val_loss: 0.4004 - val_accuracy: 0.8566
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3644 - accuracy: 0.8697 - val_loss: 0.3964 - val_accuracy: 0.8571
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3536 - accuracy: 0.8748 - val_loss: 0.4008 - val_accuracy: 0.8560
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3448 - accuracy: 0.8768 - val_loss: 0.3822 - val_accuracy: 0.8650

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 4))

axs[0].plot(history.history['loss'], label='loss', color='blue')
axs[0].plot(history.history['val_loss'], label='val_loss', color='red')
axs[0].legend()

axs[1].plot(history.history['accuracy'], label='accuracy', color='blue')
axs[1].plot(history.history['val_accuracy'], label='val_accuracy', color='red')
axs[1].legend()

plt.show()

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
idx = 20
plt.imshow(x_train[idx])
plt.show()

# %%
x_train[0].shape
# Out:
# (32, 32, 3)

# %%
x_train_flattened = x_train.reshape(-1, 32 * 32 * 3)
x_test_flattened = x_test.reshape(-1, 32 * 32 * 3)

# %%
x_train_flattened = x_train_flattened / 255.
x_test_flattened = x_test_flattened / 255.

# %%
model = keras.Sequential([
    keras.Input(32 * 32 * 3, name='input_layer'),
    keras.layers.Dense(128, activation='relu', name='fc_1'),
    keras.layers.Dense(128, activation='relu', name='fc_2'),
    keras.layers.Dense(10, activation='softmax', name='output_layer')
], name='mnist_classifier')

# %%
model.summary()
# Out:
# Model: "mnist_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  fc_1 (Dense)                (None, 128)               393344
#
#  fc_2 (Dense)                (None, 128)               16512
#
#  output_layer (Dense)        (None, 10)                1290
#
# =================================================================
# Total params: 411146 (1.57 MB)
# Trainable params: 411146 (1.57 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='sgd',
    metrics=['accuracy']
)

# %%
history = model.fit(x_train_flattened,
          y_train,
          validation_data=(x_test_flattened, y_test),
          epochs=10,
          batch_size=32,
)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.8971 - accuracy: 0.3213 - val_loss: 1.8285 - val_accuracy: 0.3298
# Epoch 2/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.7083 - accuracy: 0.3935 - val_loss: 1.6655 - val_accuracy: 0.4082
# Epoch 3/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6301 - accuracy: 0.4230 - val_loss: 1.5850 - val_accuracy: 0.4376
# Epoch 4/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5754 - accuracy: 0.4438 - val_loss: 1.5567 - val_accuracy: 0.4506
# Epoch 5/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5302 - accuracy: 0.4597 - val_loss: 1.5280 - val_accuracy: 0.4534
# Epoch 6/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4961 - accuracy: 0.4720 - val_loss: 1.5460 - val_accuracy: 0.4534
# Epoch 7/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4670 - accuracy: 0.4815 - val_loss: 1.5362 - val_accuracy: 0.4548
# Epoch 8/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4419 - accuracy: 0.4895 - val_loss: 1.4869 - val_accuracy: 0.4715
# Epoch 9/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4148 - accuracy: 0.4986 - val_loss: 1.4428 - val_accuracy: 0.4932
# Epoch 10/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3932 - accuracy: 0.5058 - val_loss: 1.4536 - val_accuracy: 0.4822

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 4))

axs[0].plot(history.history['loss'], label='loss', color='blue')
axs[0].plot(history.history['val_loss'], label='val_loss', color='red')
axs[0].legend()

axs[1].plot(history.history['accuracy'], label='accuracy', color='blue')
axs[1].plot(history.history['val_accuracy'], label='val_accuracy', color='red')
axs[1].legend()

plt.show()

# %%
network = keras.Sequential([
    layers.Input(shape=(32, 32, 3), name='input_layer'),
    layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', name='conv_1_1'),
    layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', name='conv_1_2'),
    layers.MaxPooling2D(2, name='pool_1'),

    layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu', name='conv_2_1'),
    layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu', name='conv_2_2'),
    layers.MaxPooling2D(2, name='pool_2'),

    layers.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu', name='conv_3_1'),
    layers.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu', name='conv_3_2'),
    layers.MaxPooling2D(2, name='pool_3'),

    layers.Flatten(name='flatten_layer'),

    layers.Dense(128, activation='relu', name='fc_1'),
    # layers.Dropout(.2, name='dropout'),

    layers.Dense(10, activation='softmax', name='output_layer'),
])

# %%
network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1_1 (Conv2D)           (None, 32, 32, 32)        896
#
#  conv_1_2 (Conv2D)           (None, 32, 32, 32)        9248
#
#  pool_1 (MaxPooling2D)       (None, 16, 16, 32)        0
#
#  conv_2_1 (Conv2D)           (None, 16, 16, 64)        18496
#
#  conv_2_2 (Conv2D)           (None, 16, 16, 64)        36928
#
#  pool_2 (MaxPooling2D)       (None, 8, 8, 64)          0
#
#  conv_3_1 (Conv2D)           (None, 8, 8, 128)         73856
#
#  conv_3_2 (Conv2D)           (None, 8, 8, 128)         147584
#
#  pool_3 (MaxPooling2D)       (None, 4, 4, 128)         0
#
#  flatten_layer (Flatten)     (None, 2048)              0
#
#  fc_1 (Dense)                (None, 128)               262272
#
#  output_layer (Dense)        (None, 10)                1290
#
# =================================================================
# Total params: 550570 (2.10 MB)
# Trainable params: 550570 (2.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
network.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
history = network.fit(x_train,
          y_train,
          validation_data=(x_test, y_test),
          epochs=10,
          batch_size=32,
)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 15s 7ms/step - loss: 1.4780 - accuracy: 0.4727 - val_loss: 1.0733 - val_accuracy: 0.6190
# Epoch 2/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.0085 - accuracy: 0.6491 - val_loss: 1.0543 - val_accuracy: 0.6443
# Epoch 3/10
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.8438 - accuracy: 0.7068 - val_loss: 0.8680 - val_accuracy: 0.7010
# Epoch 4/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.7485 - accuracy: 0.7413 - val_loss: 0.8434 - val_accuracy: 0.7122
# Epoch 5/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.6817 - accuracy: 0.7636 - val_loss: 0.8357 - val_accuracy: 0.7259
# Epoch 6/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.6234 - accuracy: 0.7835 - val_loss: 0.8234 - val_accuracy: 0.7273
# Epoch 7/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.5745 - accuracy: 0.8011 - val_loss: 0.8557 - val_accuracy: 0.7197
# Epoch 8/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.5367 - accuracy: 0.8149 - val_loss: 0.8575 - val_accuracy: 0.7237
# Epoch 9/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.4990 - accuracy: 0.8255 - val_loss: 0.8831 - val_accuracy: 0.7335
# Epoch 10/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.4547 - accuracy: 0.8406 - val_loss: 0.8932 - val_accuracy: 0.7356

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 4))

axs[0].plot(history.history['loss'], label='loss', color='blue')
axs[0].plot(history.history['val_loss'], label='val_loss', color='red')
axs[0].legend()

axs[1].plot(history.history['accuracy'], label='accuracy', color='blue')
axs[1].plot(history.history['val_accuracy'], label='val_accuracy', color='red')
axs[1].legend()

plt.show()
